# %%
from scipy import stats
import numpy as np
rng=np.random.default_rng()
sample1=stats.uniform.rvs(size=100,random_state=rng)
sample2=stats.norm.rvs(size=110,random_state=rng)
stats.ks_2samp(sample1,sample2)
# Out:
# KstestResult(statistic=0.5354545454545454, pvalue=2.6257767313586975e-14, statistic_location=0.025926198065201, statistic_sign=-1)

# %%
#anomly in my dataset
#
#1.High Null value
2.Missing Columns
3.outlier
4.categorical
Gender-->Male,Female

# %%
import pandas as pd
df = pd.read_csv("/config/workspace/artifact/02192023__094548/data_ingestion/dataset/train.csv")

# %%
len(df.iloc[:,[0]].drop("class",axis=1).columns)
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# class         0
# aa_000        0
# ab_000    22300
# ac_000     1697
# ad_000     7335
#           ...
# ee_007      301
# ee_008      301
# ee_009      301
# ef_000     1376
# eg_000     1375
# Length: 171, dtype: int64

# %%
drop_column_names=[]
for column_name,missing_percentage in zip((df.isnull().sum()/df.shape[0]).index,(df.isnull().sum()/df.shape[0]).values):
    print(column_name,missing_percentage)
    if missing_percentage>0.3:
        drop_column_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 0.770293609671848
# ac_000 0.058618307426597585
# ad_000 0.2533678756476684
# ae_000 0.043454231433506046
# af_000 0.043454231433506046
# ag_000 0.010362694300518135
# ag_001 0.010362694300518135
# ag_002 0.010362694300518135
# ag_003 0.010362694300518135
# ag_004 0.010362694300518135
# ag_005 0.010362694300518135
# ag_006 0.010362694300518135
# ag_007 0.010362694300518135
# ag_008 0.010362694300518135
# ag_009 0.010362694300518135
# ah_000 0.010189982728842832
# ai_000 0.009810017271157167
# aj_000 0.009810017271157167
# ak_000 0.07651122625215889
# al_000 0.00998272884283247
# am_0 0.009810017271157167
# an_000 0.00998272884283247
# ao_000 0.009050086355785837
# ap_000 0.00998272884283247
# aq_000 0.009050086355785837
# ar_000 0.047495682210708115
# as_000 0.009810017271157167
# at_000 0.009810017271157167
# au_000 0.009810017271157167
# av_000 0.0434887737478411
# ax_000 0.043523316062176166
# ay_000 0.010397236614853195
# ay_001 0.010397236614853195
# ay_002 0.010397236614853195
# ay_003 0.010397236614853195
# ay_004 0.010397236614853195
# ay_005 0.010397236614853195
# ay_006 0.010397236614853195
# ay_007 0.010397236614853195
# ay_008 0.010397236614853195
# ay_009 0.010397236614853195
# az_000 0.010397236614853195
# az_001 0.010397236614853195
# az_002 0.010397236614853195
# az_003 0.010397236614853195
# az_004 0.010397236614853195
# az_005 0.010397236614853195
# az_006 0.010397236614853195
# az_007 0.010397236614853195
# az_008 0.010397236614853195
# az_009 0.010397236614853195
# ba_000 0.010569948186528497
# ba_001 0.010569948186528497
# ba_002 0.010569948186528497
# ba_003 0.010569948186528497
# ba_004 0.010569948186528497
# ba_005 0.010569948186528497
# ba_006 0.010569948186528497
# ba_007 0.010569948186528497
# ba_008 0.010569948186528497
# ba_009 0.010569948186528497
# bb_000 0.010189982728842832
# bc_000 0.047564766839378235
# bd_000 0.0475993091537133
# be_000 0.04355785837651122
# bf_000 0.043454231433506046
# bg_000 0.00998272884283247
# bh_000 0.00998272884283247
# bi_000 0.009050086355785837
# bj_000 0.009050086355785837
# bk_000 0.3819343696027634
# bl_000 0.4504663212435233
# bm_000 0.6574784110535405
# bn_000 0.7294991364421416
# bo_000 0.7666321243523316
# bp_000 0.7890846286701209
# bq_000 0.8063903281519862
# br_000 0.8152331606217617
# bs_000 0.011364421416234888
# bt_000 0.002487046632124352
# bu_000 0.010846286701208982
# bv_000 0.010846286701208982
# bx_000 0.05305699481865285
# by_000 0.007426597582037997
# bz_000 0.047495682210708115
# ca_000 0.07585492227979275
# cb_000 0.011364421416234888
# cc_000 0.05305699481865285
# cd_000 0.010880829015544042
# ce_000 0.04355785837651122
# cf_000 0.2533678756476684
# cg_000 0.2533678756476684
# ch_000 0.2533678756476684
# ci_000 0.005595854922279792
# cj_000 0.005595854922279792
# ck_000 0.005595854922279792
# cl_000 0.15872193436960277
# cm_000 0.1646286701208981
# cn_000 0.010535405872193437
# cn_001 0.010535405872193437
# cn_002 0.010535405872193437
# cn_003 0.010535405872193437
# cn_004 0.010535405872193437
# cn_005 0.010535405872193437
# cn_006 0.010535405872193437
# cn_007 0.010535405872193437
# cn_008 0.010535405872193437
# cn_009 0.010535405872193437
# co_000 0.2533678756476684
# cp_000 0.04753022452504318
# cq_000 0.010846286701208982
# cr_000 0.770293609671848
# cs_000 0.010362694300518135
# cs_001 0.010362694300518135
# cs_002 0.010362694300518135
# cs_003 0.010362694300518135
# cs_004 0.010362694300518135
# cs_005 0.010362694300518135
# cs_006 0.010362694300518135
# cs_007 0.010362694300518135
# cs_008 0.010362694300518135
# cs_009 0.010362694300518135
# ct_000 0.23423143350604492
# cu_000 0.23423143350604492
# cv_000 0.23423143350604492
# cx_000 0.23423143350604492
# cy_000 0.23423143350604492
# cz_000 0.23423143350604492
# da_000 0.23423143350604492
# db_000 0.23423143350604492
# dc_000 0.23423143350604492
# dd_000 0.043592400690846286
# de_000 0.04753022452504318
# df_000 0.07015544041450777
# dg_000 0.07015544041450777
# dh_000 0.07015544041450777
# di_000 0.07008635578583765
# dj_000 0.07012089810017272
# dk_000 0.07012089810017272
# dl_000 0.07015544041450777
# dm_000 0.07018998272884283
# dn_000 0.010846286701208982
# do_000 0.04753022452504318
# dp_000 0.0475993091537133
# dq_000 0.0475993091537133
# dr_000 0.047564766839378235
# ds_000 0.0475993091537133
# dt_000 0.0475993091537133
# du_000 0.047564766839378235
# dv_000 0.047564766839378235
# dx_000 0.047495682210708115
# dy_000 0.04753022452504318
# dz_000 0.047495682210708115
# ea_000 0.047495682210708115
# eb_000 0.07012089810017272
# ec_00 0.17094991364421416
# ed_000 0.15872193436960277
# ee_000 0.010397236614853195
# ee_001 0.010397236614853195
# ee_002 0.010397236614853195
# ee_003 0.010397236614853195
# ee_004 0.010397236614853195
# ee_005 0.010397236614853195
# ee_006 0.010397236614853195
# ee_007 0.010397236614853195
# ee_008 0.010397236614853195
# ee_009 0.010397236614853195
# ef_000 0.04753022452504318
# eg_000 0.047495682210708115

# %%
null_report=df.isnull().sum()/df.shape[0]
null_report[null_report>0.3].index
# Out:
# Index(['ab_000', 'bk_000', 'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000',
#        'bq_000', 'br_000', 'cr_000'],
#       dtype='object')
